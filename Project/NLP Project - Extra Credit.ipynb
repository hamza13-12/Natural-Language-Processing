# %% [markdown]
# ## Task 1

# %%
import pandas as pd
import spacy
import re
import string

# %%
nlp = spacy.load('en_core_web_sm')

# %%
name_pattern = re.compile(
    r'^(Mr\.|Ms\.|Mrs\.|Dr\.|Miss|Mx\.|Sir|Madam)?\s*'  # Optional titles
    r'([A-Z][a-zA-Z\'\-]+,\s*)?'  # Optional last name followed by a comma and space (for "Last, First" format)
    r'[A-Z][a-zA-Z\'\-]+'  # First name
    r'(\s[A-Z][a-zA-Z\'\-]+)*'  # Optional middle names
    r'(\s(Jr\.|Sr\.|II|III))?$'  # Optional suffixes
)

# %%
def validate_name(df, column_name):
    def is_valid_name(text):
        # Detect "PERSON" entities
        doc = nlp(text)
        for ent in doc.ents:
            if ent.label_ == 'PERSON':
                return True
        
        # Check using reg exp
        if bool(name_pattern.match(str(text))):
            return True

        # Return False if neither verifies the name
        return False
    
    # Apply the combined validation function
    validation_results = df[column_name].apply(is_valid_name)
    
    return validation_results

# %%
if __name__ == "__main__":
    # Assuming that recall is more important in this case
    input_file = 'dev_data.csv'
    df = pd.read_csv(input_file)
    
    # Validate Person Names
    df['Person Name Valid'] = validate_name(df, 'Person Name')
    
    # Save df
    df.to_csv('processed_dev_data.csv', index=False)

    # Load df
    df = pd.read_csv('processed_dev_data.csv')

    validation_counts = df['Person Name Valid'].value_counts()
    print(validation_counts)

    invalid_names = df[df['Person Name Valid'] == False]['Person Name']
    print(invalid_names)
# Out:
# Person Name Valid
# True    1000
# Name: count, dtype: int64
# Series([], Name: Person Name, dtype: object)

# %% [markdown]
# ## Task 2

# %%
def clean_name(df, col_name, split=False, name_format="first_last", case_type="sentence", remove_punctuation=True, standardize="FN,LN"):
    # split (boolean): True, False
    # name_format options: first_last, last_first (applied only when split = True)
    # standardize options: "FN, LN", "LN,FN" (without spaces) (applied only when split = False)
    # case types: upper, lower, sentence 
    
    # Helper function to detect salutation
    def detect_salutation(name):
        salutations = ["Mr", "Mrs", "Ms", "Dr", "Prof", "Miss", "Sir", "Lady", "Mr.", "Ms.", "Dr."]
        tokens = name.split()
        if tokens[0] in salutations:
            return tokens[0], ' '.join(tokens[1:])
        return "", name

    # Helper function to split names based on the presence of a comma
    def split_name(name):
        if ',' in name:
            # Case where format is "LName, FName"
            last, first = name.split(',', 1)
            last, first = last.strip(), first.strip()
        else:
            # Assume "FName LName" format
            tokens = name.split()
            if len(tokens) == 1:
                first, last = tokens[0], ""
            else:
                first, last = tokens[0], ' '.join(tokens[1:])
        return first, last

    # Create new columns if split=True
    if split:
        df['Salutation'] = ""
        df['First Name'] = ""
        df['Last Name'] = ""

    # Process each name
    for idx, row in df.iterrows():
        original_name = row[col_name]

        # Remove punctuation according to param
        if remove_punctuation:
            original_name = original_name.translate(str.maketrans('', '', string.punctuation))

        # Handle salutations
        salutation, cleaned_name = detect_salutation(original_name)

        # Split or Standardize the names based on split param
        if split:
            # Remove salutation for splitting
            first, last = split_name(cleaned_name)
            df.at[idx, 'Salutation'] = salutation

            if name_format == "last_first":
                df.at[idx, 'First Name'] = last  # In last_first, first name goes to last
                df.at[idx, 'Last Name'] = first  # Last name goes to first
            else:
                df.at[idx, 'First Name'] = first
                df.at[idx, 'Last Name'] = last
        else:
            first, last = split_name(cleaned_name)

            if standardize == "LN,FN":
                # Split cleaned name and assume the last token is the last name
                name_tokens = cleaned_name.split()
                if len(name_tokens) > 1:
                    last = name_tokens[-1]  # Last token is treated as the last name
                    first = ' '.join(name_tokens[:-1])  # Rest are treated as first name
                else:
                    first = name_tokens[0]  # If only one token, it's the first name, no last name

                standardized_name = f"{last} {first}"
            else:
                standardized_name = f"{first} {last}"

            if salutation and salutation not in standardized_name.split():
                standardized_name = f"{salutation} {standardized_name}"

            df.at[idx, col_name] = standardized_name

        # Apply casing
        if case_type == "upper":
            df.at[idx, col_name] = df.at[idx, col_name].upper()
        elif case_type == "lower":
            df.at[idx, col_name] = df.at[idx, col_name].lower()
        elif case_type == "sentence":
            df.at[idx, col_name] = ' '.join(word.capitalize() for word in df.at[idx, col_name].split())
            
    if split and name_format == "last_first":
        df = df.rename(columns={"First Name": "Last Name", "Last Name": "First Name"})

    return df

# %%
def main(file_name):
    df = pd.read_csv(file_name)
    processed_df = clean_name(df, "Person Name", split=True, name_format="last_first", case_type="sentence", remove_punctuation=True, standardize="LN,FN")
    processed_df.to_csv('processed_' + file_name, index=False)

# %%
main("dev_data.csv")

# %%
pd.read_csv("processed_dev_data.csv")
# Out:
#                     Person Name                      Company Name   Currency  \
# 0         Ms. Stephanie Frazier            Carter, Combs and Boyd    $7,450
# 1         Mr Mateo Cortez-gomez                      Humphrey Ltd   6277 CAD
# 2         Dr Ahmed Abdel Rahman            Prime Industries, Inc.  $9812 CAD
# 3        Dr. Isabella Rodriguez                Alpha Technologies  $2817 CAD
# 4            Mr. Matthew Jensen            Blue Wave Technologies    712 AUD
# 5               Smith, Patricia               NextGen Enterprises  $4015 USD
# 6                Ms Sarah Clark          Innovative Designs, Inc.   5064 AUD
# 7                Christian Dyer          Kelly, Gray and Faulkner  $3916 AUD
# 8              Mrs Diane Walker                  Henderson-Sexton  $2460 CAD
# 9              Mrs. Monica Ross              Creative Minds, Ltd.   6309 AUD
# 10            Jonathan Garrison                      Lynch-Abbott  $1198 CAD
# 11                Emily Johnson              Creative Minds, Ltd.    $2,153
# 12                Nicole Austin         Hopkins, Holder and Brown    $3,895
# 13               Michael Lee Jr            Prime Industries, Inc.   4332 USD
# 14                Emily Johnson                Green Energy, Inc.    $5,448
# 15             Thomas Glenn Jr.        Bailey, Stewart and Harris    $9,057
# 16           Mateo Cortez-gomez                Smart Systems, LLC  $9560 AUD
# 17                 Joshua Ortiz                      Bailey Group   8034 CAD
# 18                   Maria Diaz                   Data I Am, Inc.  $8427 CAD
# 19               Jeremy Coleman                        Ross-White  $8104 AUD
# 20                Crystal Wells          Advanced Analytics, Inc.    $8,976
# 21             Victor Schneider                     Everett-Combs    $6,958
# 22                   Sean Barry                Richards-Fernandez    263 USD
# 23          Santiago Perez-luna        Rivera, Santana and Martin  $2569 AUD
# 24             Shannon Gonzalez                         Green LLC   5856 USD
# 76                   Kevin Moss                  Maxwell-Thompson  $9124 USD
# 77           Ahmed Abdel Rahman            Prime Industries, Inc.   4313 AUD
# 78               Dillon Gilmore          Advanced Analytics, Inc.   8832 AUD
# 79                Zachary Olson            Blue Wave Technologies  $8046 AUD
# 80                   Peter Hale              Tech Solutions, Inc.    $8,509
# 81               Benjamin Adams              Creative Minds, Ltd.  $9218 AUD
# 82               Carlos Sanchez   Burns, Gallagher and Villarreal   6107 USD
# 83                Stephen Clark                        Martin PLC  $4810 USD
# 84                 Robert Brown                    SecureNet, LLC    $6,643
# 85                  Kathy Perez            Blue Wave Technologies  $5128 AUD
# 86                  David White                Alpha Technologies   5801 AUD
# 87           Juan Carlos Rivera          Parker, Thomas and Floyd    976 CAD
# 88              Christy Johnson           Myers, Welch and Rogers  $6691 AUD
# 89                Melinda Combs               Visionary Solutions    $5,240
# 90          Santiago Perez-luna          Innovative Designs, Inc.  $9507 AUD
# 91                Lydia Salazar            Wall, Ellis and Wright    $3,050
# 92                   Ali Hassan              Tech Solutions, Inc.    $5,062
# 93                    Lori Park            Blue Wave Technologies   1867 AUD
# 94                   Cindy Diaz         Morris, Griffin and White  $4252 CAD
# 95           Mateo Cortez-gomez                       Cooper-Hall   5069 AUD
# 96                   Brian Hunt          Johnson, Lee and Johnson   2400 USD
# 97                 Robert Brown              Jordan, Young and Ho  $2842 USD
# 98               Michael Taylor              Omega Holdings, Inc.   7753 AUD
# 99                Emily Johnson         Lucas, Brown and Thompson    $1,530
# 100             Michael Chapman               NextGen Enterprises  $7916 AUD
# 101            Mitchell Cameron            Prime Industries, Inc.    $1,775
# 102                Robert Brown               NextGen Enterprises   7215 CAD
# 103          Ahmed Abdel Rahman             Future Pathways, Inc.  $7140 CAD
# 104                  Maria Diaz                     Johnson-Rojas   7590 CAD
# 105                  Ali Hassan               NextGen Enterprises  $6637 USD
# 106                Robert Brown                    Smith and Sons    $6,998
# 107                 Chris Green                Alpha Technologies    $9,455
# 108                April Kelley               Visionary Solutions   8170 CAD
# 109               Andrew Thomas            Blue Wave Technologies  $3257 CAD
# 110                  Cathy Wood              Creative Minds, Ltd.   2544 CAD
# 111               Fatima Zainab                        Duarte Ltd  $9148 AUD
# 112         Brenda Blackwell Md             Future Pathways, Inc.    $2,047
# 113                 Mateo Lopez            Blue Wave Technologies  $8366 USD
# 114                 Mateo Lopez           ProTech Solutions, Inc.  $3534 USD
# 115                 Sarah Clark                      Marshall PLC   8507 AUD
# 116                Robert Brown            Blue Wave Technologies    556 AUD
# 117               Fatima Zainab                       Roberts Ltd  $5040 AUD
# 118             Bethany Johnson            Blue Wave Technologies   8507 USD
# 119             Ayesha Siddiqui                         Baker PLC      $328
# 120          Mateo Cortez-gomez                     Rogers-Taylor   $307 USD
# 121               Fatima Zainab                Alpha Technologies   9437 CAD
# 122                 Chris Green               NextGen Enterprises  $8037 USD
# 123                  Max Finley                  Walters-Garrison  $4874 CAD
# 124                 Sarah Clark                     Dyer and Sons   3959 CAD
# 125               Emily Johnson         Taylor, Ellis and Johnson   $693 USD
# 585             James Rodriguez           ProTech Solutions, Inc.    $5,923
# 586                 David Hicks                    Lopez-Martinez   7022 USD
# 587                Robert Brown                   Mcclure-Hoffman  $8863 CAD
# 588         Santiago Perez-luna           Lang, Rosales and Stone    $3,778
# 589                Cheryl Lewis             Future Pathways, Inc.    $2,897
# 590                 Chris Green               NextGen Enterprises   9365 CAD
# 591                  Tom Harris                         Smith PLC   8063 CAD
# 592                 Michael Lee          Innovative Designs, Inc.   7768 CAD
# 593                  Bryan Hunt            Prime Industries, Inc.    $8,155
# 594             Timothy Alvarez                       Brown-Grant   6205 CAD
# 595                Megan Rogers                Green Energy, Inc.    $8,820
# 596            Dr. Aaron Cannon                    Montgomery PLC   7098 CAD
# 597                  Tom Harris                          Orr-Boyd    $7,998
# 598                Jason Butler                    Henderson-Ryan  $8923 CAD
# ...
# 674        NaN          Rodriguez     Isabella
# 675        NaN             Bryant       Jeremy
# 676        NaN           Fletcher        Kelly
# 677        NaN  Khalil Anwar Khan     Muhammad
# 678        NaN              Smith         Jane
# 679        NaN              Smith         Jane
# 680        NaN            Johnson        Emily
# 681        NaN          PerezLuna     Santiago
# 682        NaN               Diaz        Maria
# 683        NaN              Smith         Jane
# 684        NaN            Johnson        Emily
# 685        NaN      Carlos Rivera         Juan
# 686        NaN            Serrano       Sierra
# 687        NaN            Chapman        Joyce
# 688        NaN           Matthews        Wanda
# 689        NaN                Lee      Michael
# 690        NaN              Clark        Sarah
# 691        NaN             Walker         Mike
# 692        NaN            Johnson        Emily
# 693        NaN              Ortiz       Joshua
# 694        NaN            Sanchez       Carlos
# 695        NaN            Serrano        Corey
# 696        NaN               Love        Carla
# 697        NaN  Khalil Anwar Khan     Muhammad
# 698        NaN            Chapman        Renee
# 699        NaN              Boyle        Tyler
# 700        NaN            Bradley  Christopher
# 701        NaN          PerezLuna     Santiago
# 702        NaN               Lara      Matthew
# 703        NaN             Morgan      Charles
# 704        NaN      Carlos Rivera         Juan
# 705        NaN            Andrade        Danny
# 706        NaN               Shah       Ashley
# 707        NaN       Abdel Rahman        Ahmed
# 708        NaN             Hassan          Ali
# 709        NaN           Robinson          Don
# 710        NaN              Smith      Zachary
# 711        NaN               Diaz        Maria
# 712        NaN              White        David
# 713        NaN            Sanchez       Carlos
# 714        NaN              Lopez        Mateo
# 715        NaN             Ashley       Sandra
# 716        NaN               Ward        Kelly
# 717        NaN              Foley       Lauren
# 718        NaN              Burch     Jennifer
# 719        NaN               Paul       Robert
# 720        NaN            Sweeney      Preston
# 721        NaN              Mcgee      Richard
# 722        NaN            Johnson      Michael
# 723        NaN            Johnson        Emily
# 724        NaN                Doe         John
# 725        NaN              Smith         Jane
# 726        NaN           Siddiqui       Ayesha
# 727        NaN             Zainab       Fatima
# 728        NaN              James         Lori
# 729        NaN              Lopez        Mateo
# 730        NaN              Brown       Daniel
# 731        NaN                Doe         John
# 732        NaN          PerezLuna     Santiago
# 733        NaN          Rodriguez     Isabella
# 734        NaN              Brown       Robert
# 735        NaN              Combs         Ryan
# 736        NaN            Hickman      Cynthia
# 737        NaN          Gallagher      Zachary
# 738        NaN            Sanchez       Carlos
# 739        NaN        CortezGomez        Mateo
# 740        NaN               Ruiz         John
# 741        NaN                Doe         John
# 742        NaN              Craig     Kimberly
# 743        NaN            Goodman     Danielle
# 744        NaN                Lee      Michael
# 745        NaN              Stone       Meagan
# 746        NaN             Zainab       Fatima
# 747        NaN            Johnson        Emily
# 748        NaN             Carter      William
# 749        NaN        Martinez Jr          Joe
# 750        NaN            Jackson      Jessica
# 751        NaN  Khalil Anwar Khan     Muhammad
# 752        NaN                Lee      Michael
# 753        NaN             Graham         Mark
# 754        NaN  Khalil Anwar Khan     Muhammad
# 755        NaN            Johnson      Richard
# 756        NaN          PerezLuna     Santiago
# 757        NaN              White        David
# 758        NaN           Mcdonald     Courtney
# 759        NaN            Douglas      Ricardo
# 760        NaN             Nelson       Samuel
# 761        NaN               Diaz        Maria
# 762        NaN              Brown       Robert
# 763        NaN               Cook        Tammy
# 764        NaN           Woodward      Gregory
# 765        NaN            Johnson        Julie
# 766        NaN          PerezLuna     Santiago
# 767        NaN           Siddiqui       Ayesha
# 768        NaN           Gonzales         Jeff
# 769        NaN              Clark        Sarah
# 770        NaN          Waters MD    Elizabeth
# 771        NaN            Donovan      Richard
# 772        NaN          PerezLuna     Santiago
# 773        NaN              Green        Chris
# 774        NaN              Brown       Robert
# 775        NaN           Siddiqui       Ayesha
# 776        NaN                Doe         John
# 777        NaN               Hill       Rhonda
# 778        NaN              White        David
# 779        NaN              Clark        Sarah
# 780        NaN              Lopez        Mateo
# 781        NaN          Rodriguez     Isabella
# 782        NaN          PerezLuna     Santiago
# 783        NaN               Diaz        Maria
# 784        NaN            Rosario      Mallory
# 785        NaN       Abdel Rahman        Ahmed
# 786        NaN               Gray    Christina
# 787        NaN       Abdel Rahman        Ahmed
# 788        NaN             Cooley       Hailey
# 789        NaN              Black        Linda
# 790        NaN              Green        Chris
# 791        NaN               Bean     Mitchell
# 792        NaN               Long       Joshua
# 793        NaN            Burnett     Brittany
# 794        NaN              Gates         Ryan
# 795        NaN              Black        Linda
# 796        NaN          Rodriguez     Isabella
# 797        NaN              Jones         Eric
# 798        NaN             Garcia          Dan
# 799        NaN              Clark        Sarah
# 800        NaN                Doe         John
# 801        NaN              Lopez        Tammy
# 802        NaN             Miller      Kenneth
# 803        NaN              Tyler      Stephen
# 804        NaN            Bennett      Shannon
# 805        NaN            Parrish       Daniel
# 806        NaN              Clark        Sarah
# 807        NaN            Johnson       Sharon
# 808        NaN            Sanchez       Carlos
# 809        NaN          Rodriguez     Isabella
# 810        NaN          Carpenter       George
# 811        NaN              James        Donna
# 812        NaN             Harris      Jeffrey
# 813        NaN               Pena         Erin
# 814        NaN             Murphy         Lisa
# 815        NaN              Lopez        Mateo
# 816        NaN              Brown       Robert
# 817        NaN            Russell      Charles
# 818        NaN              Green        Chris
# 819        NaN             Benson    Elizabeth
# 820        NaN                Liu       Jeremy
# 821        NaN              Hicks        Brian
# 822        NaN              White        David
# 823        NaN              Smith         Jane
# 824        NaN           Martinez     Michelle
# 825        NaN            Bernard    Alexandra
# 826        NaN              Smith         Jane
# 827        NaN              White        David
# 828        NaN  Khalil Anwar Khan     Muhammad
# 829        NaN               Pham         Dana
# 830        NaN            Sanchez       Carlos
# 831        NaN                Lee      Michael
# 832        NaN           Gonzalez       Darius
# 833        NaN             Thomas       Joshua
# 834        NaN           Chandler        James
# 835        NaN            Sanchez       Carlos
# 836        NaN             Palmer     Kimberly
# 837        NaN            Wallace        Jenna
# 838        NaN             Parker        James
# 839        NaN             Fowler    Alexandra
# 840        NaN        CortezGomez        Mateo
# 841        NaN               Diaz        Maria
# 842        NaN              Scott        Larry
# 843        NaN            Mendoza        Holly
# 844        NaN  Khalil Anwar Khan     Muhammad
# 845        NaN  Khalil Anwar Khan     Muhammad
# 846        NaN            Griffin    Katherine
# 847        NaN              Brown       Robert
# 848        NaN          Dougherty        Karen
# 849        NaN              Brown       Robert
# 850        NaN          PerezLuna     Santiago
# 851        NaN             Conner        Julia
# 852        NaN              Clark        Sarah
# 853        NaN              Green        Chris
# 854        NaN          PerezLuna     Santiago
# 855        NaN               Diaz       Dustin
# 856        NaN        CortezGomez        Mateo
# 857        NaN  Khalil Anwar Khan     Muhammad
# 858        NaN             Thomas      Michael
# 859        NaN        Odonnell MD        April
# 860        NaN             Zainab       Fatima
# 861        NaN           Jennings        Tyler
# 862        NaN              Smith         Jane
# 863        NaN  Khalil Anwar Khan     Muhammad
# 864        NaN             Hughes          Lee
# 865        NaN              Drake       Nathan
# 866        NaN              Brown       Robert
# 867        NaN              Stone     Jonathan
# 868        NaN        CortezGomez        Mateo
# 869        NaN               Sims        Angel
# 870        NaN             Harris      Charles
# 871        NaN       Abdel Rahman        Ahmed
# 872        NaN        Lambert DDS       Ashley
# 873        NaN                Cox      Jeffrey
# 874        NaN              Smith         Jane
# 875        NaN                Doe         John
# 876        NaN            Collins         Mark
# 877        NaN              Brown       Robert
# 878        NaN              Stone  Christopher
# 879        NaN             Taylor       Joshua
# 880        NaN              Smith         Jane
# 881        NaN             Zainab       Fatima
# 882        NaN                Lee      Michael
# 883        NaN                Lee         Jill
# 884        NaN          Rodriguez         Adam
# 885        NaN              Ortiz         Eric
# 886        NaN              Silva        Kevin
# 887        NaN               Pena       Collin
# 888        NaN              Dixon        Jason
# 889        NaN              Brown       Robert
# 890        NaN        CortezGomez        Mateo
# 891        NaN                Lee         Luis
# 892        NaN             Turner         Emma
# 893        NaN      Carlos Rivera         Juan
# 894        NaN             Miller       Dennis
# 895        NaN           Williams        Karen
# 896        NaN           Townsend    Christina
# 897        NaN        CortezGomez        Mateo
# 898        NaN              Brown       Robert
# 899        NaN             Zainab       Fatima
# 900        NaN             Howard        Debra
# 901        NaN        CortezGomez        Mateo
# 902        NaN             Daniel       Nicole
# 903        NaN              Perez         Mary
# 904        NaN               Mora       Joseph
# 905        NaN              White        David
# 906        NaN  Khalil Anwar Khan     Muhammad
# 907        NaN              Brown        David
# 908        NaN            Johnson         Eric
# 909        NaN             Martin       Lauren
# 910        NaN               Gray      Heather
# 911        NaN              Clark        Sarah
# 912        NaN              Dixon        Peter
# 913        NaN              Lopez        Mateo
# 914        NaN              Lopez        Mateo
# 915        NaN              Lopez        Mateo
# 916        NaN            Johnson        Emily
# 917        NaN               Ward      Abigail
# 918        NaN             Harper        Diane
# 919        NaN           Williams      Heather
# 920        NaN             Murphy      Michael
# 921        NaN           Saunders        David
# 922        NaN               Lang        Heidi
# 923        NaN             Peters       Rachel
# 924        NaN             Dorsey          Amy
# 925        NaN              Perez       Nathan
# 926        NaN               Horn      Charles
# 927        NaN               Diaz        Maria
# 928        NaN              Smith         Jane
# 929        NaN             Morrow      Allison
# 930        NaN            Ramirez    Elizabeth
# 931        NaN             Murphy       Amanda
# 932        NaN            Sanchez      Stanley
# 933        NaN              Lopez        Mateo
# 934        NaN               Rose       Travis
# 935        NaN               Cole        David
# 936        NaN           Fletcher        James
# 937        NaN        CortezGomez        Mateo
# 938        NaN            Johnson        Emily
# 939        NaN             Zainab       Fatima
# 940        NaN        CortezGomez        Mateo
# 941        NaN  Khalil Anwar Khan     Muhammad
# 942        NaN            Griffin     Meredith
# 943        NaN              White        David
# 944        NaN           Siddiqui       Ayesha
# 945        NaN            Leonard         Sean
# 946         Mr          Austin MD        Bryce
# 947        NaN      Carlos Rivera         Juan
# 948        NaN           Anderson          Amy
# 949        NaN              Davis        Linda
# 950        NaN          Logan DDS     Victoria
# 951        NaN             Hansen       Ashlee
# 952        NaN             Fuller       Andrew
# 953        NaN            Sanchez       Carlos
# 954        NaN              Lopez        Mateo
# 955        NaN        CortezGomez        Mateo
# 956        NaN             Flores     Veronica
# 957        NaN             Thomas      Brandon
# 958        NaN            Bradley      Lindsay
# 959        NaN            Beasley       Lauren
# 960        NaN           Martinez       Justin
# 961        NaN             Hassan          Ali
# 962        NaN            Ballard         Juan
# 963        NaN             Phelps       Joseph
# 964        NaN                Lee      Michael
# 965        NaN              Cohen      Timothy
# 966        NaN              Clark        Sarah
# 967        NaN          PerezLuna     Santiago
# 968        NaN  Khalil Anwar Khan     Muhammad
# 969        NaN             Jordan       Lauren
# 970        NaN        CortezGomez        Mateo
# 971        NaN          PerezLuna     Santiago
# 972        NaN            Pearson        Wyatt
# 973        NaN                Doe         John
# 974        NaN            Schmidt         Ryan
# 975        NaN          Rodriguez     Isabella
# 976        NaN               Diaz        Maria
# 977        NaN  Khalil Anwar Khan     Muhammad
# 978        NaN               West        Terri
# 979        NaN              White        David
# 980        NaN            Collins      Kaitlyn
# 981        NaN              Smith       Steven
# 982        NaN              White         Cody
# 983        NaN      Carlos Rivera         Juan
# 984        NaN           Reynolds       Joseph
# 985        NaN             Atkins         Gary
# 986        NaN          PerezLuna     Santiago
# 987        NaN              Black        Linda
# 988        NaN              Black        Linda
# 989        NaN          PerezLuna     Santiago
# 990        NaN             Graves      Michael
# 991        NaN                Doe         John
# 992        NaN            Benitez         Jose
# 993        NaN             Harris          Tom
# 994        NaN             Harris          Tom
# 995        NaN              Lopez        Mateo
# 996        NaN               Diaz        Maria
# 997        NaN             Thomas       Nicole
# 998        NaN              Green        Chris
# 999        NaN           Johnston       Summer
